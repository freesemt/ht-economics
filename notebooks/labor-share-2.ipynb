# %%
import sys
sys.path.insert(0, '..')
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ["MS Gothic"]  # "MS Gothic", "MS Mincho", "Meiryo"
from ht_economics.LaborShare import load_laborshare_data, plot_laborshare

# %%
years, wages, incomes1, incomes2 = load_laborshare_data('../data/2023ffm2_jp.xlsx')
plot_laborshare(years, wages, incomes1, incomes2)
